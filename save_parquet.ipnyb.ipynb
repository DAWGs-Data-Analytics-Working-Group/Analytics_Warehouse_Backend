# %%
import pandas as pd
import numpy as np
import os
from typing import Iterator, Union, List, Optional
from pathlib import Path
import shutil

# %%
# Read the CSV and extract column names as a list
cols = pd.read_csv("columns.csv")["Column Names"].tolist()

print(cols)  # Display the list of column names

xlsx_files = [f for f in os.listdir('./planning_data/Monthly Ped Reports') if f.endswith(('.xlsx', '.xlsm'))]
xlsx_files
# Out:
# ['From', 'To Time', 'Z01_T4-ChurchSt_RevDoor_IN', 'Z01_T4-ChurchSt_RevDoor_OUT', 'Z01_T4-ChurchSt_SwingDoor_IN', 'Z01_T4-ChurchSt_SwingDoor_OUT', 'Z02_T4-LibertySt_EastEsc46_IN', 'Z02_T4-LibertySt_EastEsc46_OUT', 'Z02_T4-LibertySt_WestEsc45_IN', 'Z02_T4-LibertySt_WestEsc45_OUT', 'Z02_T4-LibertySt_Stair_IN', 'Z02_T4-LibertySt_Stair_OUT', 'Z02_T4-LibertySt_Doors_IN', 'Z02_T4-LibertySt_Doors_OUT', 'Z03_T4-C1-StairEsc_StairElev_IN', 'Z03_T4-C1-StairEsc_StairElev_OUT', 'Z03_T4-C1-StairEsc_EastEsc46_IN', 'Z03_T4-C1-StairEsc_EastEsc46_OUT', 'Z03_T4-C1-StairEsc_WestEsc45_IN', 'Z03_T4-C1-StairEsc_WestEsc45_OUT', 'Z04_T4-SoConc-Entry_AllDoors_IN', 'Z04_T4-SoConc-Entry_AllDoors_OUT', 'Z05_WestProj-Street_NorthDoors_IN', 'Z05_WestProj-Street_NorthDoors_OUT', 'Z05_WestProj-Street_SouthDoors_IN', 'Z05_WestProj-Street_SouthDoors_OUT', 'Z06_WestProj-C1-StairEsc_NorthStair_IN', 'Z06_WestProj-C1-StairEsc_NorthStair_OUT', 'Z06_WestProj-C1-StairEsc_NorthEsc36_IN', 'Z06_WestProj-C1-StairEsc_NorthEsc36_OUT', 'Z06_WestProj-C1-StairEsc_Elev_OUTOFELEV', 'Z06_WestProj-C1-StairEsc_Elev_INTOELEV', 'Z06_WestProj-C1-StairEsc_SouthEsc35_IN', 'Z06_WestProj-C1-StairEsc_SouthEsc35_OUT', 'Z06_WestProj-C1-StairEsc_SouthStair_IN', 'Z06_WestProj-C1-StairEsc_SouthStair_OUT', 'Z07_EastProj-Street_NorthDoors_IN', 'Z07_EastProj-Street_NorthDoors_OUT', 'Z07_EastProj-Street_SouthDoors_IN', 'Z07_EastProj-Street_SouthDoors_OUT', 'Z08_EastProj-C1-StairEsc_Elev_OUTOFELEV', 'Z08_EastProj-C1-StairEsc_Elev_INTOELEV', 'Z08_EastProj-C1-StairEsc_NorthEsc39_IN', 'Z08_EastProj-C1-StairEsc_NorthEsc39_OUT', 'Z08_EastProj-C1-StairEsc_NorthStair_IN', 'Z08_EastProj-C1-StairEsc_NorthStair_OUT', 'Z08_EastProj-C1-StairEsc_SouthStair_IN', 'Z08_EastProj-C1-StairEsc_SouthStair_OUT', 'Z08_EastProj-C1-StairEsc_SouthEsc37_IN', 'Z08_EastProj-C1-StairEsc_SouthEsc37_OUT', 'Z09_DeyStConc-Entry_NorthDoors_IN', 'Z09_DeyStConc-Entry_NorthDoors_OUT', 'Z09_DeyStConc-Entry_SouthDoors_IN', 'Z09_DeyStConc-Entry_SouthDoors_OUT', 'Z10_ETrain-HistoricEntry_Stair_IN', 'Z10_ETrain-HistoricEntry_Stair_OUT', 'Z11_T2-VeseySt_EastEsc47_IN', 'Z11_T2-VeseySt_EastEsc47_OUT', 'Z11_T2-VeseySt_Stair_IN', 'Z11_T2-VeseySt_Stair_OUT', 'Z11_T2-VeseySt_WestEsc48_IN', 'Z11_T2-VeseySt_WestEsc48_OUT', 'Z11_T2-VeseySt_StreetDoors_IN', 'Z11_T2-VeseySt_StreetDoors_OUT', 'Z12_T2-FultonSt_BwColumn&SouthWall_IN', 'Z12_T2-FultonSt_BwColumn&SouthWall_OUT', 'Z12_T2-FultonSt_AllDoors_IN', 'Z12_T2-FultonSt_AllDoors_OUT', 'Z12_T2-FultonSt_BwColumn&EastWall_IN', 'Z12_T2-FultonSt_BwColumn&EastWall_OUT', 'Z13_T1-Office-Entry_Gen-EastMostRevDoor_IN', 'Z13_T1-Office-Entry_Gen-EastMostRevDoor_OUT', 'Z13_T1-Office-Entry_Conde-WestRevDoor_IN', 'Z13_T1-Office-Entry_Conde-WestRevDoor_OUT', 'Z13_T1-Office-Entry_Conde-CenterSwingDoors_IN', 'Z13_T1-Office-Entry_Conde-CenterSwingDoors_OUT', 'Z13_T1-Office-Entry_Passageway-West_WB', 'Z13_T1-Office-Entry_Passageway-West_EB', 'Z13_T1-Office-Entry_Conde-EastRevDoor_IN', 'Z13_T1-Office-Entry_Conde-EastRevDoor_OUT', 'Z13_T1-Office-Entry_Gen-2ndEastMostRevDoor_IN', 'Z13_T1-Office-Entry_Gen-2ndEastMostRevDoor_OUT', 'Z13_T1-Office-Entry_Gen-WestSwingDoors_IN', 'Z13_T1-Office-Entry_Gen-WestSwingDoors_OUT', 'Z13_T1-Office-Entry_Gen-WestMostRevDoor_IN', 'Z13_T1-Office-Entry_Gen-WestMostRevDoor_OUT', 'Z13_T1-Office-Entry_Gen-2ndWestMostRevDoor_IN', 'Z13_T1-Office-Entry_Gen-2ndWestMostRevDoor_OUT', 'Z13_T1-Office-Entry_Passageway-East_WB', 'Z13_T1-Office-Entry_Passageway-East_EB', 'Z14_T1-Observatory-Entry_WestSwingDoors_IN', 'Z14_T1-Observatory-Entry_WestSwingDoors_OUT', 'Z14_T1-Observatory-Entry_EastSwingDoors_IN', 'Z14_T1-Observatory-Entry_EastSwingDoors_OUT', 'Z14_T1-Observatory-Entry_WestRevDoor_IN', 'Z14_T1-Observatory-Entry_WestRevDoor_OUT', 'Z14_T1-Observatory-Entry_EastRevDoor_IN', 'Z14_T1-Observatory-Entry_EastRevDoor_OUT', 'Z14_T1-Observatory-Entry_Passageway-East_WB', 'Z14_T1-Observatory-Entry_Passageway-East_EB', 'Z14_T1-Observatory-Entry_Elev_OUTOFELEV', 'Z14_T1-Observatory-Entry_Elev_INTOELEV', 'Z14_T1-O ...
# ['2020-03_WTC-PED-MONTHLY-RPT-v3.1.xlsx']

# %%
for file in xlsx_files:
    file_path = os.path.join('./planning_data/Monthly Ped Reports', file)
    arch_path = os.path.join('./planning_data/Monthly Ped Reports/processed', file)

    try:
        # Read the Excel file with specified columns
        df = pd.read_excel(file_path, sheet_name="Data", usecols=cols, engine="openpyxl")
        df = df[df["From"].notnull()]
        print(f"Successfully read: {file}")
        parquet_filename = f"./planning_data/ped_report_parquet/{file.replace('.xlsx', '.parquet')}"
        df.to_parquet(parquet_filename, engine="pyarrow", index=False)
        print(f"Parquet file saved: {parquet_filename}")
        dest = shutil.move(file_path, arch_path) 

    except Exception as e:
        print(f"Error reading {file}: {e}")
else:
    print("No valid data to save.")
# Out:
# Successfully read: 2020-03_WTC-PED-MONTHLY-RPT-v3.1.xlsx
# Parquet file saved: ./planning_data/ped_report_parquet/2020-03_WTC-PED-MONTHLY-RPT-v3.1.parquet
# No valid data to save.
